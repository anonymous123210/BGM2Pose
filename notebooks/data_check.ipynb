# %%
import pandas as pd

data = pd.read_csv("../pose_estimation/dataset_spec_2400/music_intensity.csv")

# %%
data.testee.value_counts()
# Out:
# testee
# subject_1    4021
# subject_0    2561
# subject_9    2544
# subject_6    2544
# subject_8    2544
# subject_7    2544
# subject_5    2149
# subject_3    2149
# subject_2    2149
# subject_4    2149
# Name: count, dtype: int64

# %%
train_data = pd.read_csv("../pose_estimation/csv/kfold_same_music_wo_subject_1_3_subject_0_all/train.csv")
train_data.testee.value_counts()
# Out:
# testee
# subject_6    2544
# subject_7    2544
# subject_8    2544
# subject_9    2544
# subject_5    2149
# subject_2    2149
# subject_4    2149
# Name: count, dtype: int64
